# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 1: MOUNT GOOGLE DRIVE
# ═══════════════════════════════════════════════════════════════════════════
from google.colab import drive
drive.mount('/content/drive')

# !pip uninstall -y numpy
# !pip install numpy==1.26.4

# !pip install -q tensorflow-model-optimization
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
# ^C

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 2: INSTALL DEPENDENCIES
# ═══════════════════════════════════════════════════════════════════════════
# Fix: split thành 2 lệnh riêng biệt
# !pip uninstall -y numpy
# !pip install numpy==1.26.4
# !pip install -q tensorflow-model-optimization

# Chạy các lệnh trên trong cell riêng trước khi chạy script này
# Sau đó RESTART RUNTIME rồi chạy từ đây

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU: {tf.config.list_physical_devices('GPU')}")

# ── Import tfmot sau khi đã cài ──────────────────────────────────────────
try:
    import tensorflow_model_optimization as tfmot
    QAT_AVAILABLE = True
    print("✅ tensorflow-model-optimization ready")
except ImportError:
    QAT_AVAILABLE = False
    print("⚠️  QAT không khả dụng — sẽ dùng PTQ thay thế")
# Out:
# TensorFlow version: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ tensorflow-model-optimization ready

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 3: LOAD & VERIFY ASIC DATA
# ═══════════════════════════════════════════════════════════════════════════
DRIVE_PATH  = '/content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/PreprocessedData_ASIC'
OUTPUT_PATH = '/content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models'
os.makedirs(OUTPUT_PATH, exist_ok=True)

SCALE_FACTOR = 128.0
IMG_SIZE     = 128
BATCH_SIZE   = 32

def load_asic_data(drive_path=DRIVE_PATH):
    print("=" * 70)
    print("LOADING ASIC-OPTIMIZED DATA")
    print("=" * 70)

    files = {
        'X_train': os.path.join(drive_path, 'X_train_asic.npy'),
        'X_test':  os.path.join(drive_path, 'X_test_asic.npy'),
        'y_train': os.path.join(drive_path, 'y_train_asic.npy'),
        'y_test':  os.path.join(drive_path, 'y_test_asic.npy'),
    }
    for name, path in files.items():
        if not os.path.exists(path):
            raise FileNotFoundError(f"❌ Không tìm thấy: {path}")
        print(f"  ✅ {name}: {path}")

    X_train = np.load(files['X_train'])
    X_test  = np.load(files['X_test'])
    y_train = np.load(files['y_train'])
    y_test  = np.load(files['y_test'])

    print(f"\n📊 Format gốc (Q0.7 int8):")
    print(f"  X_train: shape={X_train.shape}, dtype={X_train.dtype}, range=[{X_train.min()}, {X_train.max()}]")
    print(f"  X_test:  shape={X_test.shape}")
    print(f"  y_train: shape={y_train.shape}, classes={np.unique(y_train)}")

    assert X_train.dtype == np.int8, "❌ X_train phải là int8"
    assert X_train.shape[1] == IMG_SIZE and X_train.shape[2] == IMG_SIZE, \
        f"❌ Kích thước phải là {IMG_SIZE}x{IMG_SIZE}"
    assert (IMG_SIZE & (IMG_SIZE - 1)) == 0, "❌ IMG_SIZE phải là power-of-2"
    print(f"\n✅ Xác nhận ASIC format: int8, {IMG_SIZE}x{IMG_SIZE} (power-of-2)")

    print(f"\n🔄 Chuyển đổi: int8 / {SCALE_FACTOR:.0f} → float32")
    X_train_f = X_train.astype(np.float32) / SCALE_FACTOR
    X_test_f  = X_test.astype(np.float32)  / SCALE_FACTOR
    print(f"  X_train float32 range: [{X_train_f.min():.4f}, {X_train_f.max():.4f}]")

    X_train_f = np.expand_dims(X_train_f, axis=-1)
    X_test_f  = np.expand_dims(X_test_f,  axis=-1)

    print(f"\n📐 Shape sau khi thêm channel:")
    print(f"  X_train: {X_train_f.shape}")
    print(f"  X_test:  {X_test_f.shape}")

    for split_name, y in [('Train', y_train), ('Test', y_test)]:
        unique, counts = np.unique(y, return_counts=True)
        print(f"\n📊 {split_name} class distribution:")
        for cls, cnt in zip(unique, counts):
            label = "Fatigue (0)" if cls == 0 else "Active  (1)"
            print(f"  {label}: {cnt:4d}  ({100*cnt/len(y):.1f}%)")

    print("\n" + "=" * 70)
    print("✅ DATA READY")
    print("=" * 70)
    return X_train_f, X_test_f, y_train, y_test


X_train, X_test, y_train, y_test = load_asic_data()
# Out:
# ======================================================================
# LOADING ASIC-OPTIMIZED DATA
# ======================================================================
#   ✅ X_train: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/PreprocessedData_ASIC/X_train_asic.npy
#   ✅ X_test: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/PreprocessedData_ASIC/X_test_asic.npy
#   ✅ y_train: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/PreprocessedData_ASIC/y_train_asic.npy
#   ✅ y_test: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/PreprocessedData_ASIC/y_test_asic.npy
#
# 📊 Format gốc (Q0.7 int8):
#   X_train: shape=(7296, 128, 128), dtype=int8, range=[0, 127]
#   X_test:  shape=(1824, 128, 128)
#   y_train: shape=(7296,), classes=[0 1]
#
# ✅ Xác nhận ASIC format: int8, 128x128 (power-of-2)
#
# 🔄 Chuyển đổi: int8 / 128 → float32
#   X_train float32 range: [0.0000, 0.9922]
#
# 📐 Shape sau khi thêm channel:
#   X_train: (7296, 128, 128, 1)
#   X_test:  (1824, 128, 128, 1)
#
# 📊 Train class distribution:
#   Fatigue (0): 3648  (50.0%)
#   Active  (1): 3648  (50.0%)
#
# 📊 Test class distribution:
#   Fatigue (0):  912  (50.0%)
#   Active  (1):  912  (50.0%)
#
# ======================================================================
# ✅ DATA READY
# ======================================================================

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 4: DATA AUGMENTATION (tf.data pipeline)
# ═══════════════════════════════════════════════════════════════════════════
# FIX: Bỏ random_brightness và random_contrast vì data đã ở dạng Q0.7
# (int8/128) — brightness/contrast shift làm lệch distribution so với
# calibration set, gây accuracy drop sau quantization.
# Chỉ giữ flip + noise nhẹ để augment mà không thay đổi scale.
AUTOTUNE = tf.data.AUTOTUNE

def augment(image, label):
    # Flip ngang — safe với driver face data
    image = tf.image.random_flip_left_right(image)
    # Gaussian noise rất nhỏ (std=0.01 ≈ 1.3 LSB ở int8) — simulate sensor noise
    # KHÔNG dùng brightness/contrast vì gây distribution shift với Q0.7 input
    noise = tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=0.01)
    image = image + noise
    # Clip đúng range Q0.7: [-1.0, 1.0) tương ứng int8 [-128, 127] / 128
    image = tf.clip_by_value(image, -1.0, 1.0)
    return image, label

train_dataset = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train.astype(np.float32)))
    .shuffle(buffer_size=len(X_train), seed=42)
    .map(augment, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_dataset = (
    tf.data.Dataset.from_tensor_slices((X_test, y_test.astype(np.float32)))
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# FIX: bỏ // để không bỏ sót batch cuối (drop_remainder=False mặc định)
# train_steps=None → Keras tự đếm toàn bộ batches
train_steps = None
test_steps  = None

print(f"✅ tf.data pipeline ready")
print(f"  Train samples : {len(X_train)}")
print(f"  Test samples  : {len(X_test)}")
print(f"  steps_per_epoch = None → Keras tự đếm toàn bộ batches")
# Out:
# ✅ tf.data pipeline ready
#   Train samples : 7296
#   Test samples  : 1824
#   steps_per_epoch = None → Keras tự đếm toàn bộ batches

# %%
#═════════════════════════════════════════════════════════════
# STEP 5 (SỬA LẠI): BUILD MODEL — fix BN range issue từ diagnostic
# ═══════════════════════════════════════════════════════════════════════════
#
# Vấn đề từ diagnostic:
#   - BN layers có range 17–25 → int8 resolution chỉ ~0.1/step → mất thông tin
#   - conv4_proj range 25.08 (worst), output range 23.16
#   - Weights OK (< 0.6), KHÔNG phải outlier weight
#
# Fix:
#   1. Đổi thứ tự: Conv → BN → ReLU6  (hiện tại: Conv → ReLU6 → BN cho một số layer)
#      ReLU6 clamp ở 6 → BN output bị giới hạn [-6, 6] → range giảm từ 25 xuống ~6
#   2. conv4_proj: thêm ReLU6 sau BN để clamp range
#   3. output layer: KHÔNG quantize → giữ float32, sigmoid tính ngoài


def build_asic_model(input_shape=(128, 128, 1)):
    inputs = tf.keras.Input(shape=input_shape, name="input_q07")

    # ===== Block 0: Quantize input (ignore in full precision) =====
    x = inputs  # chỉ giữ input layer

    # ===== Block 1 ===== (128 → 64)
    x = tf.keras.layers.DepthwiseConv2D(3, padding='same', use_bias=False, name='depthwise_conv1')(x)
    x = tf.keras.layers.Conv2D(32, 1, padding='same', use_bias=False, name='conv1')(x)
    x = tf.keras.layers.BatchNormalization(name='bn1')(x)
    x = tf.keras.layers.ReLU(max_value=6, name='relu1')(x)
    x = tf.keras.layers.MaxPooling2D(2, name='pool1')(x)

    # ===== Block 2 ===== (64 → 32)
    x = tf.keras.layers.DepthwiseConv2D(3, padding='same', use_bias=False, name='depthwise_conv2')(x)
    x = tf.keras.layers.Conv2D(64, 1, padding='same', use_bias=False, name='conv2')(x)
    x = tf.keras.layers.BatchNormalization(name='bn2')(x)
    x = tf.keras.layers.ReLU(max_value=6, name='relu2')(x)
    x = tf.keras.layers.MaxPooling2D(2, name='pool2')(x)

    # ===== Block 3 ===== (32 → 16)
    x = tf.keras.layers.DepthwiseConv2D(3, padding='same', use_bias=False, name='depthwise_conv3')(x)
    x = tf.keras.layers.Conv2D(128, 1, padding='same', use_bias=False, name='conv3')(x)
    x = tf.keras.layers.BatchNormalization(name='bn3')(x)
    x = tf.keras.layers.ReLU(max_value=6, name='relu3')(x)
    x = tf.keras.layers.MaxPooling2D(2, name='pool3')(x)

    # ===== Block 4 (Light Residual) =====
    # Skip branch
    skip = tf.keras.layers.Conv2D(128, 1, padding='same', use_bias=False, name='conv4_proj')(x)
    skip = tf.keras.layers.BatchNormalization(name='bn4_proj')(skip)

    # Main branch
    x = tf.keras.layers.DepthwiseConv2D(3, padding='same', use_bias=False, name='depthwise_conv4')(x)
    x = tf.keras.layers.Conv2D(128, 1, padding='same', use_bias=False, name='conv4')(x)
    x = tf.keras.layers.BatchNormalization(name='bn4')(x)
    x = tf.keras.layers.ReLU(max_value=6, name='relu4')(x)

    # Add skip connection
    x = tf.keras.layers.Add(name='skip_add')([x, skip])
    x = tf.keras.layers.ReLU(max_value=6, name='relu4b')(x)

    # ===== Head =====
    x = tf.keras.layers.GlobalAveragePooling2D(name='gap')(x)
    x = tf.keras.layers.Dense(64, use_bias=False, name='fc1')(x)
    x = tf.keras.layers.BatchNormalization(name='bn_fc1')(x)
    x = tf.keras.layers.ReLU(max_value=6, name='relu_fc1')(x)
    x = tf.keras.layers.Dropout(0.5, name='drop1')(x)
    outputs = tf.keras.layers.Dense(1, use_bias=True, name='output')(x)

    return tf.keras.Model(inputs, outputs, name="full_precision_model")

base_model = build_asic_model()

print("=" * 70)
print("ASIC MODEL ARCHITECTURE")
print("=" * 70)
base_model.summary()

total_params = base_model.count_params()
print(f"\n📊 ASIC Resource Estimate:")
print(f"  Total parameters : {total_params:,}")
print(f"  Weight memory    : {total_params/1024:.1f} KB (int8 sau quantize)")
# Out:
# ======================================================================
# ASIC MODEL ARCHITECTURE
# ======================================================================
# Model: "full_precision_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_q07 (InputLayer)      [(None, 128, 128, 1)]        0         []
#
#  depthwise_conv1 (Depthwise  (None, 128, 128, 1)          9         ['input_q07[0][0]']
#  Conv2D)
#
#  conv1 (Conv2D)              (None, 128, 128, 32)         32        ['depthwise_conv1[0][0]']
#
#  bn1 (BatchNormalization)    (None, 128, 128, 32)         128       ['conv1[0][0]']
#
#  relu1 (ReLU)                (None, 128, 128, 32)         0         ['bn1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 64, 64, 32)           0         ['relu1[0][0]']
#
#  depthwise_conv2 (Depthwise  (None, 64, 64, 32)           288       ['pool1[0][0]']
#  Conv2D)
#
#  conv2 (Conv2D)              (None, 64, 64, 64)           2048      ['depthwise_conv2[0][0]']
#
#  bn2 (BatchNormalization)    (None, 64, 64, 64)           256       ['conv2[0][0]']
#
#  relu2 (ReLU)                (None, 64, 64, 64)           0         ['bn2[0][0]']
#
#  pool2 (MaxPooling2D)        (None, 32, 32, 64)           0         ['relu2[0][0]']
#
#  depthwise_conv3 (Depthwise  (None, 32, 32, 64)           576       ['pool2[0][0]']
#  Conv2D)
#
#  conv3 (Conv2D)              (None, 32, 32, 128)          8192      ['depthwise_conv3[0][0]']
#
#  bn3 (BatchNormalization)    (None, 32, 32, 128)          512       ['conv3[0][0]']
#
#  relu3 (ReLU)                (None, 32, 32, 128)          0         ['bn3[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 16, 16, 128)          0         ['relu3[0][0]']
#
#  depthwise_conv4 (Depthwise  (None, 16, 16, 128)          1152      ['pool3[0][0]']
#  Conv2D)
#
#  conv4 (Conv2D)              (None, 16, 16, 128)          16384     ['depthwise_conv4[0][0]']
#
#  bn4 (BatchNormalization)    (None, 16, 16, 128)          512       ['conv4[0][0]']
#
#  conv4_proj (Conv2D)         (None, 16, 16, 128)          16384     ['pool3[0][0]']
#
#  relu4 (ReLU)                (None, 16, 16, 128)          0         ['bn4[0][0]']
#
#  bn4_proj (BatchNormalizati  (None, 16, 16, 128)          512       ['conv4_proj[0][0]']
#  on)
#
#  skip_add (Add)              (None, 16, 16, 128)          0         ['relu4[0][0]',
#                                                                      'bn4_proj[0][0]']
#
#  relu4b (ReLU)               (None, 16, 16, 128)          0         ['skip_add[0][0]']
#
#  gap (GlobalAveragePooling2  (None, 128)                  0         ['relu4b[0][0]']
#  D)
#
#  fc1 (Dense)                 (None, 64)                   8192      ['gap[0][0]']
#
#  bn_fc1 (BatchNormalization  (None, 64)                   256       ['fc1[0][0]']
#  )
#
#  relu_fc1 (ReLU)             (None, 64)                   0         ['bn_fc1[0][0]']
#
#  drop1 (Dropout)             (None, 64)                   0         ['relu_fc1[0][0]']
#
#  output (Dense)              (None, 1)                    65        ['drop1[0][0]']
#
# ==================================================================================================
# Total params: 55498 (216.79 KB)
# Trainable params: 54410 (212.54 KB)
# Non-trainable params: 1088 (4.25 KB)
# __________________________________________________________________________________________________
#
# 📊 ASIC Resource Estimate:
#   Total parameters : 55,498
#   Weight memory    : 54.2 KB (int8 sau quantize)

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 6: TRAIN BASE MODEL (FLOAT32) — với fixes cho quantization
# ═══════════════════════════════════════════════════════════════════════════
print("=" * 70)
print("STEP 6: TRAINING BASE FLOAT32 MODEL")
print("=" * 70)

BASE_EPOCHS = 40  # FIX: tăng từ 30→40, EarlyStopping vẫn kiểm soát

base_model.compile(
    optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=1e-3),
    # label_smoothing=0.05: model không overconfident → logit nhỏ hơn
    # → activation range hẹp → int8 quantize ít mất mát hơn
    loss=tf.keras.losses.BinaryCrossentropy(
        from_logits=True,
        label_smoothing=0.05
    ),
    metrics=['accuracy']
)

base_ckpt_path = os.path.join(OUTPUT_PATH, 'base_best.weights.h5')

callbacks_base = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=10,            # FIX: tăng patience để không dừng sớm
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=4,             # FIX: tăng patience để LR không giảm quá sớm
        min_lr=1e-6,
        verbose=1
    ),
    # FIX: thêm ModelCheckpoint — backup an toàn hơn restore_best_weights
    # vì restore_best_weights đôi khi fail khi kết hợp với custom training loop
    tf.keras.callbacks.ModelCheckpoint(
        filepath=base_ckpt_path,
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=True,
        verbose=1
    ),
]

print(f"Training {BASE_EPOCHS} epochs (với early stopping + checkpoint)...\n")

history_base = base_model.fit(
    train_dataset,
    epochs=BASE_EPOCHS,
    validation_data=test_dataset,
    steps_per_epoch=train_steps,   # None → dùng toàn bộ batches
    validation_steps=test_steps,   # None → dùng toàn bộ batches
    callbacks=callbacks_base,
    verbose=1
)

# Load best checkpoint để đảm bảo chắc chắn dùng weights tốt nhất
base_model.load_weights(base_ckpt_path)
base_loss, base_acc = base_model.evaluate(X_test, y_test, verbose=0)
print(f"\n✅ Base model (float32) accuracy: {base_acc*100:.2f}%")

if base_acc < 0.93:
    print(f"⚠️  WARNING: Base accuracy {base_acc*100:.2f}% < 93% target")
    print(f"   → Kiểm tra lại data quality hoặc tăng BASE_EPOCHS")
else:
    print(f"✅ Base accuracy đạt yêu cầu (>93%) — tiến hành QAT")

base_weights_path = os.path.join(OUTPUT_PATH, 'base_weights.weights.h5')
base_model.save_weights(base_weights_path)
print(f"💾 Weights saved: {base_weights_path}")
# Out:
# ======================================================================
# STEP 6: TRAINING BASE FLOAT32 MODEL
# ======================================================================
# Training 40 epochs (với early stopping + checkpoint)...
#
# Epoch 1/40
# 228/228 [==============================] - ETA: 0s - loss: 0.6267 - accuracy: 0.6708
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 14s 27ms/step - loss: 0.6267 - accuracy: 0.6708 - val_loss: 0.6946 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7429
# Epoch 2: val_accuracy did not improve from 0.50000
# 228/228 [==============================] - 5s 23ms/step - loss: 0.5347 - accuracy: 0.7433 - val_loss: 0.8254 - val_accuracy: 0.4995 - lr: 0.0010
# Epoch 3/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.4890 - accuracy: 0.7661
# Epoch 3: val_accuracy improved from 0.50000 to 0.71875, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 7s 32ms/step - loss: 0.4889 - accuracy: 0.7666 - val_loss: 0.5271 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 4/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.4494 - accuracy: 0.7930
# Epoch 4: val_accuracy improved from 0.71875 to 0.83004, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 7s 32ms/step - loss: 0.4499 - accuracy: 0.7925 - val_loss: 0.4217 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 5/40
# 228/228 [==============================] - ETA: 0s - loss: 0.4225 - accuracy: 0.8154
# Epoch 5: val_accuracy did not improve from 0.83004
# 228/228 [==============================] - 6s 28ms/step - loss: 0.4225 - accuracy: 0.8154 - val_loss: 0.6038 - val_accuracy: 0.6508 - lr: 0.0010
# Epoch 6/40
# 228/228 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8203
# Epoch 6: val_accuracy did not improve from 0.83004
# 228/228 [==============================] - 5s 23ms/step - loss: 0.4084 - accuracy: 0.8203 - val_loss: 0.4167 - val_accuracy: 0.7928 - lr: 0.0010
# Epoch 7/40
# 228/228 [==============================] - ETA: 0s - loss: 0.3877 - accuracy: 0.8350
# Epoch 7: val_accuracy did not improve from 0.83004
# 228/228 [==============================] - 5s 23ms/step - loss: 0.3877 - accuracy: 0.8350 - val_loss: 0.3986 - val_accuracy: 0.8037 - lr: 0.0010
# Epoch 8/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.3707 - accuracy: 0.8473
# Epoch 8: val_accuracy improved from 0.83004 to 0.86897, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 8s 33ms/step - loss: 0.3702 - accuracy: 0.8475 - val_loss: 0.4063 - val_accuracy: 0.8690 - lr: 0.0010
# Epoch 9/40
# 228/228 [==============================] - ETA: 0s - loss: 0.3733 - accuracy: 0.8510
# Epoch 9: val_accuracy did not improve from 0.86897
# 228/228 [==============================] - 5s 23ms/step - loss: 0.3733 - accuracy: 0.8510 - val_loss: 2.1136 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 10/40
# 228/228 [==============================] - ETA: 0s - loss: 0.3638 - accuracy: 0.8554
# Epoch 10: val_accuracy did not improve from 0.86897
# 228/228 [==============================] - 7s 30ms/step - loss: 0.3638 - accuracy: 0.8554 - val_loss: 0.4951 - val_accuracy: 0.7999 - lr: 0.0010
# Epoch 11/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.3455 - accuracy: 0.8662
# Epoch 11: val_accuracy did not improve from 0.86897
# 228/228 [==============================] - 5s 23ms/step - loss: 0.3455 - accuracy: 0.8662 - val_loss: 0.3828 - val_accuracy: 0.8531 - lr: 0.0010
# Epoch 12/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.3483 - accuracy: 0.8662
# Epoch 12: val_accuracy did not improve from 0.86897
# 228/228 [==============================] - 6s 24ms/step - loss: 0.3472 - accuracy: 0.8672 - val_loss: 0.4204 - val_accuracy: 0.7867 - lr: 0.0010
# Epoch 13/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.3405 - accuracy: 0.8728
# Epoch 13: val_accuracy improved from 0.86897 to 0.87226, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 7s 33ms/step - loss: 0.3398 - accuracy: 0.8732 - val_loss: 0.3605 - val_accuracy: 0.8723 - lr: 0.0010
# Epoch 14/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.3306 - accuracy: 0.8768
# Epoch 14: val_accuracy improved from 0.87226 to 0.88651, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 6s 24ms/step - loss: 0.3302 - accuracy: 0.8769 - val_loss: 0.3432 - val_accuracy: 0.8865 - lr: 0.0010
# Epoch 15/40
# 228/228 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8761
# Epoch 15: val_accuracy did not improve from 0.88651
# 228/228 [==============================] - 7s 30ms/step - loss: 0.3324 - accuracy: 0.8761 - val_loss: 0.4138 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 16/40
# 228/228 [==============================] - ETA: 0s - loss: 0.3275 - accuracy: 0.8797
# Epoch 16: val_accuracy did not improve from 0.88651
# 228/228 [==============================] - 5s 24ms/step - loss: 0.3275 - accuracy: 0.8797 - val_loss: 0.5506 - val_accuracy: 0.8054 - lr: 0.0010
# Epoch 17/40
# 228/228 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8847
# Epoch 17: val_accuracy did not improve from 0.88651
# 228/228 [==============================] - 7s 30ms/step - loss: 0.3151 - accuracy: 0.8847 - val_loss: 0.6195 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 18/40
# 228/228 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.8934
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 18: val_accuracy did not improve from 0.88651
# 228/228 [==============================] - 5s 24ms/step - loss: 0.3113 - accuracy: 0.8934 - val_loss: 0.5440 - val_accuracy: 0.7971 - lr: 0.0010
# Epoch 19/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.9032
# Epoch 19: val_accuracy improved from 0.88651 to 0.89693, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 7s 31ms/step - loss: 0.2954 - accuracy: 0.9032 - val_loss: 0.3424 - val_accuracy: 0.8969 - lr: 5.0000e-04
# Epoch 20/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.9034
# Epoch 20: val_accuracy improved from 0.89693 to 0.90461, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 6s 25ms/step - loss: 0.2890 - accuracy: 0.9034 - val_loss: 0.3005 - val_accuracy: 0.9046 - lr: 5.0000e-04
# Epoch 21/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.2785 - accuracy: 0.9118
# Epoch 21: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 7s 30ms/step - loss: 0.2790 - accuracy: 0.9119 - val_loss: 0.3131 - val_accuracy: 0.9013 - lr: 5.0000e-04
# Epoch 22/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.2756 - accuracy: 0.9125
# Epoch 22: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 5s 24ms/step - loss: 0.2760 - accuracy: 0.9121 - val_loss: 0.3292 - val_accuracy: 0.8898 - lr: 5.0000e-04
# Epoch 23/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.2723 - accuracy: 0.9198
# Epoch 23: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 6s 27ms/step - loss: 0.2724 - accuracy: 0.9197 - val_loss: 0.3362 - val_accuracy: 0.8816 - lr: 5.0000e-04
# Epoch 24/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2703 - accuracy: 0.9194
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 24: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 6s 27ms/step - loss: 0.2703 - accuracy: 0.9194 - val_loss: 0.4399 - val_accuracy: 0.8607 - lr: 5.0000e-04
# Epoch 25/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2596 - accuracy: 0.9228
# Epoch 25: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 5s 24ms/step - loss: 0.2594 - accuracy: 0.9230 - val_loss: 0.3108 - val_accuracy: 0.8942 - lr: 2.5000e-04
# Epoch 26/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2521 - accuracy: 0.9290
# Epoch 26: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 7s 30ms/step - loss: 0.2519 - accuracy: 0.9290 - val_loss: 0.3260 - val_accuracy: 0.8986 - lr: 2.5000e-04
# Epoch 27/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2463 - accuracy: 0.9339
# Epoch 27: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 5s 23ms/step - loss: 0.2470 - accuracy: 0.9338 - val_loss: 0.3997 - val_accuracy: 0.8794 - lr: 2.5000e-04
# Epoch 28/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2453 - accuracy: 0.9352
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 28: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 6s 26ms/step - loss: 0.2453 - accuracy: 0.9352 - val_loss: 0.3204 - val_accuracy: 0.9002 - lr: 2.5000e-04
# Epoch 29/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2397 - accuracy: 0.9367
# Epoch 29: val_accuracy did not improve from 0.90461
# 228/228 [==============================] - 6s 24ms/step - loss: 0.2394 - accuracy: 0.9370 - val_loss: 0.3216 - val_accuracy: 0.8788 - lr: 1.2500e-04
# Epoch 30/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9397
# Epoch 30: val_accuracy improved from 0.90461 to 0.90789, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 8s 34ms/step - loss: 0.2329 - accuracy: 0.9397 - val_loss: 0.3014 - val_accuracy: 0.9079 - lr: 1.2500e-04
# Epoch 31/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2345 - accuracy: 0.9422
# Epoch 31: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 5s 24ms/step - loss: 0.2348 - accuracy: 0.9419 - val_loss: 0.4438 - val_accuracy: 0.8141 - lr: 1.2500e-04
# Epoch 32/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.2343 - accuracy: 0.9430
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 32: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 7s 30ms/step - loss: 0.2343 - accuracy: 0.9430 - val_loss: 0.3074 - val_accuracy: 0.9068 - lr: 1.2500e-04
# Epoch 33/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9437
# Epoch 33: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 5s 24ms/step - loss: 0.2294 - accuracy: 0.9437 - val_loss: 0.3018 - val_accuracy: 0.9073 - lr: 6.2500e-05
# Epoch 34/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2275 - accuracy: 0.9466
# Epoch 34: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 6s 26ms/step - loss: 0.2273 - accuracy: 0.9467 - val_loss: 0.3157 - val_accuracy: 0.9041 - lr: 6.2500e-05
# Epoch 35/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.2270 - accuracy: 0.9476
# Epoch 35: val_accuracy improved from 0.90789 to 0.91173, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_best.weights.h5
# 228/228 [==============================] - 7s 31ms/step - loss: 0.2269 - accuracy: 0.9476 - val_loss: 0.2997 - val_accuracy: 0.9117 - lr: 6.2500e-05
# Epoch 36/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9442
# Epoch 36: val_accuracy did not improve from 0.91173
# 228/228 [==============================] - 5s 24ms/step - loss: 0.2280 - accuracy: 0.9442 - val_loss: 0.3150 - val_accuracy: 0.8920 - lr: 6.2500e-05
# Epoch 37/40
# 226/228 [============================>.] - ETA: 0s - loss: 0.2296 - accuracy: 0.9416
# Epoch 37: val_accuracy did not improve from 0.91173
# 228/228 [==============================] - 7s 30ms/step - loss: 0.2291 - accuracy: 0.9422 - val_loss: 0.2945 - val_accuracy: 0.9062 - lr: 6.2500e-05
# Epoch 38/40
# 228/228 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9479
# Epoch 38: val_accuracy did not improve from 0.91173
# 228/228 [==============================] - 5s 24ms/step - loss: 0.2256 - accuracy: 0.9479 - val_loss: 0.3417 - val_accuracy: 0.9030 - lr: 6.2500e-05
# Epoch 39/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2258 - accuracy: 0.9445
# Epoch 39: val_accuracy did not improve from 0.91173
# 228/228 [==============================] - 6s 28ms/step - loss: 0.2259 - accuracy: 0.9444 - val_loss: 0.3139 - val_accuracy: 0.8931 - lr: 6.2500e-05
# Epoch 40/40
# 227/228 [============================>.] - ETA: 0s - loss: 0.2232 - accuracy: 0.9485
# Epoch 40: val_accuracy did not improve from 0.91173
# 228/228 [==============================] - 6s 26ms/step - loss: 0.2229 - accuracy: 0.9487 - val_loss: 0.2952 - val_accuracy: 0.9079 - lr: 6.2500e-05
# Restoring model weights from the end of the best epoch: 35.
#
# ✅ Base model (float32) accuracy: 91.17%
# ⚠️  WARNING: Base accuracy 91.17% < 93% target
#    → Kiểm tra lại data quality hoặc tăng BASE_EPOCHS
# 💾 Weights saved: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/base_weights.weights.h5

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 7: QUANTIZATION-AWARE TRAINING (QAT) — fixed
# ═══════════════════════════════════════════════════════════════════════════
print("=" * 70)
print("STEP 7: QUANTIZATION-AWARE TRAINING (QAT)")
print("=" * 70)

QAT_EPOCHS = 30

if QAT_AVAILABLE:
    _tmp_weights = os.path.join(OUTPUT_PATH, '_tmp_base.weights.h5')
    base_model.save_weights(_tmp_weights)

    # ── FIX QUAN TRỌNG: Exclude output layer khỏi QAT ─────────────────────
    # quantize_model() mặc định quantize TẤT CẢ layers kể cả Dense output.
    # Output layer là sigmoid logit (1 neuron) — quantize int8 tại đây gây
    # mất precision nghiêm trọng vì range rất nhỏ (~[-3, 3]).
    # Giải pháp: dùng quantize_annotate_layer để skip output layer.
    quantize_annotate_layer = tfmot.quantization.keras.quantize_annotate_layer
    quantize_annotate_model = tfmot.quantization.keras.quantize_annotate_model
    quantize_apply           = tfmot.quantization.keras.quantize_apply
    LastValueQuantizer       = tfmot.quantization.keras.quantizers.LastValueQuantizer
    MovingAverageQuantizer   = tfmot.quantization.keras.quantizers.MovingAverageQuantizer

    def apply_quantization_to_layer(layer):
        # Bỏ qua output Dense layer — giữ float32 để không mất precision
        if layer.name == 'output':
            return layer
        # Bỏ qua Dropout — không cần quantize, chỉ active khi train
        if isinstance(layer, tf.keras.layers.Dropout):
            return layer
        return quantize_annotate_layer(layer)

    # Clone model và annotate từng layer theo policy trên
    annotated_model = tf.keras.models.clone_model(
        base_model,
        clone_function=apply_quantization_to_layer,
    )

    # Apply QAT (thêm fake-quant nodes vào các layer được annotate)
    qat_model = quantize_apply(annotated_model)

    # Load weights từ base model đã train (by_name để map đúng dù có thêm nodes)
    qat_model.load_weights(_tmp_weights, by_name=True, skip_mismatch=True)

    # ── FIX: LR cho QAT ────────────────────────────────────────────────────
    # LR phải rất nhỏ: QAT chỉ fine-tune để adapter fake-quant noise,
    # KHÔNG re-learn weights. LR cao phá vỡ weights đã converge tốt.
    # 5e-5 → 2e-5: giảm thêm 2.5x so với bản cũ.
    #
    # FIX: Bỏ label_smoothing trong QAT.
    # label_smoothing làm mờ gradient signal — trong QAT ta cần gradient
    # rõ ràng để model học cách compensate quantization error.
    qat_model.compile(
        optimizer=tf.keras.optimizers.legacy.Adam(
            learning_rate=2e-5,       # FIX: giảm từ 5e-5 → 2e-5
            clipnorm=1.0              # FIX: gradient clipping, tránh spike
        ),
        loss=tf.keras.losses.BinaryCrossentropy(
            from_logits=True,
            label_smoothing=0.0       # FIX: bỏ label_smoothing trong QAT
        ),
        metrics=['accuracy']
    )

    print("📊 QAT model (với fake-quant nodes, output layer excluded):")
    qat_model.summary()

    qat_ckpt_path = os.path.join(OUTPUT_PATH, 'qat_best.weights.h5')

    print(f"\n🔧 Fine-tuning QAT ({QAT_EPOCHS} epochs)...\n")

    callbacks_qat = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=10,              # FIX: tăng patience, QAT converge chậm
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,               # FIX: tăng patience
            min_lr=5e-8,              # FIX: min_lr nhỏ hơn để fine-tune cuối
            verbose=1
        ),
        # FIX: thêm checkpoint để đảm bảo luôn có best QAT weights
        tf.keras.callbacks.ModelCheckpoint(
            filepath=qat_ckpt_path,
            monitor='val_accuracy',
            save_best_only=True,
            save_weights_only=True,
            verbose=1
        ),
    ]

    history_qat = qat_model.fit(
        train_dataset,
        epochs=QAT_EPOCHS,
        validation_data=test_dataset,
        steps_per_epoch=train_steps,   # None → toàn bộ batches
        validation_steps=test_steps,   # None → toàn bộ batches
        callbacks=callbacks_qat,
        verbose=1
    )

    # Load best QAT checkpoint
    qat_model.load_weights(qat_ckpt_path)

    qat_loss, qat_acc = qat_model.evaluate(X_test, y_test, verbose=0)
    print(f"\n✅ QAT model accuracy : {qat_acc*100:.2f}%")
    print(f"   Base model accuracy: {base_acc*100:.2f}%")
    print(f"   QAT accuracy drop  : {(base_acc - qat_acc)*100:+.2f}%  (target: < 1%)")

    if qat_acc*100 < 93.0:
        print(f"⚠️  QAT accuracy {qat_acc*100:.2f}% < 93% — kiểm tra lại base accuracy")
    else:
        print(f"✅ QAT accuracy đạt target > 93%")

    qat_weights_path = os.path.join(OUTPUT_PATH, 'qat_weights.weights.h5')
    qat_model.save_weights(qat_weights_path)
    print(f"💾 QAT weights saved: {qat_weights_path}")

    model_to_export = qat_model
    history_final   = history_qat

else:
    print("⚠️  QAT không khả dụng → dùng PTQ")
    model_to_export = base_model
    history_final   = history_base
    qat_acc         = base_acc
# Out:
# ======================================================================
# STEP 7: QUANTIZATION-AWARE TRAINING (QAT)
# ======================================================================
# 📊 QAT model (với fake-quant nodes, output layer excluded):
# Model: "full_precision_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_q07 (InputLayer)      [(None, 128, 128, 1)]        0         []
#
#  quantize_layer (QuantizeLa  (None, 128, 128, 1)          3         ['input_q07[0][0]']
#  yer)
#
#  quant_depthwise_conv1 (Qua  (None, 128, 128, 1)          14        ['quantize_layer[0][0]']
#  ntizeWrapperV2)
#
#  quant_conv1 (QuantizeWrapp  (None, 128, 128, 32)         97        ['quant_depthwise_conv1[0][0]'
#  erV2)                                                              ]
#
#  quant_bn1 (QuantizeWrapper  (None, 128, 128, 32)         129       ['quant_conv1[0][0]']
#  V2)
#
#  quant_relu1 (QuantizeWrapp  (None, 128, 128, 32)         3         ['quant_bn1[0][0]']
#  erV2)
#
#  quant_pool1 (QuantizeWrapp  (None, 64, 64, 32)           1         ['quant_relu1[0][0]']
#  erV2)
#
#  quant_depthwise_conv2 (Qua  (None, 64, 64, 32)           293       ['quant_pool1[0][0]']
#  ntizeWrapperV2)
#
#  quant_conv2 (QuantizeWrapp  (None, 64, 64, 64)           2177      ['quant_depthwise_conv2[0][0]'
#  erV2)                                                              ]
#
#  quant_bn2 (QuantizeWrapper  (None, 64, 64, 64)           257       ['quant_conv2[0][0]']
#  V2)
#
#  quant_relu2 (QuantizeWrapp  (None, 64, 64, 64)           3         ['quant_bn2[0][0]']
#  erV2)
#
#  quant_pool2 (QuantizeWrapp  (None, 32, 32, 64)           1         ['quant_relu2[0][0]']
#  erV2)
#
#  quant_depthwise_conv3 (Qua  (None, 32, 32, 64)           581       ['quant_pool2[0][0]']
#  ntizeWrapperV2)
#
#  quant_conv3 (QuantizeWrapp  (None, 32, 32, 128)          8449      ['quant_depthwise_conv3[0][0]'
#  erV2)                                                              ]
#
#  quant_bn3 (QuantizeWrapper  (None, 32, 32, 128)          513       ['quant_conv3[0][0]']
#  V2)
#
#  quant_relu3 (QuantizeWrapp  (None, 32, 32, 128)          3         ['quant_bn3[0][0]']
#  erV2)
#
#  quant_pool3 (QuantizeWrapp  (None, 16, 16, 128)          1         ['quant_relu3[0][0]']
#  erV2)
#
#  quant_depthwise_conv4 (Qua  (None, 16, 16, 128)          1157      ['quant_pool3[0][0]']
#  ntizeWrapperV2)
#
#  quant_conv4 (QuantizeWrapp  (None, 16, 16, 128)          16641     ['quant_depthwise_conv4[0][0]'
#  erV2)                                                              ]
#
#  quant_bn4 (QuantizeWrapper  (None, 16, 16, 128)          513       ['quant_conv4[0][0]']
#  V2)
#
#  quant_conv4_proj (Quantize  (None, 16, 16, 128)          16641     ['quant_pool3[0][0]']
#  WrapperV2)
#
#  quant_relu4 (QuantizeWrapp  (None, 16, 16, 128)          3         ['quant_bn4[0][0]']
#  erV2)
#
#  quant_bn4_proj (QuantizeWr  (None, 16, 16, 128)          515       ['quant_conv4_proj[0][0]']
#  apperV2)
#
#  quant_skip_add (QuantizeWr  (None, 16, 16, 128)          1         ['quant_relu4[0][0]',
#  apperV2)                                                            'quant_bn4_proj[0][0]']
#
#  quant_relu4b (QuantizeWrap  (None, 16, 16, 128)          3         ['quant_skip_add[0][0]']
#  perV2)
#
#  quant_gap (QuantizeWrapper  (None, 128)                  3         ['quant_relu4b[0][0]']
#  V2)
#
#  quant_fc1 (QuantizeWrapper  (None, 64)                   8195      ['quant_gap[0][0]']
#  V2)
#
#  quant_bn_fc1 (QuantizeWrap  (None, 64)                   259       ['quant_fc1[0][0]']
#  perV2)
#
#  quant_relu_fc1 (QuantizeWr  (None, 64)                   3         ['quant_bn_fc1[0][0]']
#  apperV2)
#
#  drop1 (Dropout)             (None, 64)                   0         ['quant_relu_fc1[0][0]']
#
#  output (Dense)              (None, 1)                    65        ['drop1[1][0]']
#
# ==================================================================================================
# Total params: 56524 (220.80 KB)
# Trainable params: 54410 (212.54 KB)
# Non-trainable params: 2114 (8.26 KB)
# __________________________________________________________________________________________________
#
# 🔧 Fine-tuning QAT (30 epochs)...
#
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_layer.QuantizeLayer object at 0x7aa4a6dec620>. Skipping object. Exception encountered: Layer 'quantize_layer' expected 3 variables, but received 0 variables during loading. Expected: ['quantize_layer/quantize_layer_min:0', 'quantize_layer/quantize_layer_max:0', 'quantize_layer/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6c3e570>. Skipping object. Exception encountered: Layer 'quant_depthwise_conv1' expected 7 variables, but received 0 variables during loading. Expected: ['depthwise_conv1/depthwise_kernel:0', 'depthwise_conv1/depthwise_kernel:0', 'quant_depthwise_conv1/optimizer_step:0', 'quant_depthwise_conv1/depthwise_kernel_min:0', 'quant_depthwise_conv1/depthwise_kernel_max:0', 'quant_depthwise_conv1/post_activation_min:0', 'quant_depthwise_conv1/post_activation_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6c3d940>. Skipping object. Exception encountered: Layer 'quant_conv1' expected 5 variables, but received 0 variables during loading. Expected: ['conv1/kernel:0', 'conv1/kernel:0', 'quant_conv1/optimizer_step:0', 'quant_conv1/kernel_min:0', 'quant_conv1/kernel_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa51ed7b9b0>. Skipping object. Exception encountered: Layer 'quant_bn1' expected 3 variables, but received 0 variables during loading. Expected: ['bn1/gamma:0', 'bn1/beta:0', 'quant_bn1/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:434: UserWarning: Could not load weights in object <tf_keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa4a6d5f170>. Skipping object. Exception encountered: Layer 'bn1' expected 4 variables, but received 0 variables during loading. Expected: ['bn1/gamma:0', 'bn1/beta:0', 'bn1/moving_mean:0', 'bn1/moving_variance:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6da3d10>. Skipping object. Exception encountered: Layer 'quant_relu1' expected 3 variables, but received 0 variables during loading. Expected: ['quant_relu1/optimizer_step:0', 'quant_relu1/output_min:0', 'quant_relu1/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6c3e450>. Skipping object. Exception encountered: Layer 'quant_pool1' expected 1 variables, but received 0 variables during loading. Expected: ['quant_pool1/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6da1c10>. Skipping object. Exception encountered: Layer 'quant_depthwise_conv2' expected 7 variables, but received 0 variables during loading. Expected: ['depthwise_conv2/depthwise_kernel:0', 'depthwise_conv2/depthwise_kernel:0', 'quant_depthwise_conv2/optimizer_step:0', 'quant_depthwise_conv2/depthwise_kernel_min:0', 'quant_depthwise_conv2/depthwise_kernel_max:0', 'quant_depthwise_conv2/post_activation_min:0', 'quant_depthwise_conv2/post_activation_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6da3c50>. Skipping object. Exception encountered: Layer 'quant_conv2' expected 5 variables, but received 0 variables during loading. Expected: ['conv2/kernel:0', 'conv2/kernel:0', 'quant_conv2/optimizer_step:0', 'quant_conv2/kernel_min:0', 'quant_conv2/kernel_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6da3f20>. Skipping object. Exception encountered: Layer 'quant_bn2' expected 3 variables, but received 0 variables during loading. Expected: ['bn2/gamma:0', 'bn2/beta:0', 'quant_bn2/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:434: UserWarning: Could not load weights in object <tf_keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa4a6e471a0>. Skipping object. Exception encountered: Layer 'bn2' expected 4 variables, but received 0 variables during loading. Expected: ['bn2/gamma:0', 'bn2/beta:0', 'bn2/moving_mean:0', 'bn2/moving_variance:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6da3770>. Skipping object. Exception encountered: Layer 'quant_relu2' expected 3 variables, but received 0 variables during loading. Expected: ['quant_relu2/optimizer_step:0', 'quant_relu2/output_min:0', 'quant_relu2/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6d5f8f0>. Skipping object. Exception encountered: Layer 'quant_pool2' expected 1 variables, but received 0 variables during loading. Expected: ['quant_pool2/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6c3eea0>. Skipping object. Exception encountered: Layer 'quant_depthwise_conv3' expected 7 variables, but received 0 variables during loading. Expected: ['depthwise_conv3/depthwise_kernel:0', 'depthwise_conv3/depthwise_kernel:0', 'quant_depthwise_conv3/optimizer_step:0', 'quant_depthwise_conv3/depthwise_kernel_min:0', 'quant_depthwise_conv3/depthwise_kernel_max:0', 'quant_depthwise_conv3/post_activation_min:0', 'quant_depthwise_conv3/post_activation_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6da3ef0>. Skipping object. Exception encountered: Layer 'quant_conv3' expected 5 variables, but received 0 variables during loading. Expected: ['conv3/kernel:0', 'conv3/kernel:0', 'quant_conv3/optimizer_step:0', 'quant_conv3/kernel_min:0', 'quant_conv3/kernel_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6d5e8a0>. Skipping object. Exception encountered: Layer 'quant_bn3' expected 3 variables, but received 0 variables during loading. Expected: ['bn3/gamma:0', 'bn3/beta:0', 'quant_bn3/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:434: UserWarning: Could not load weights in object <tf_keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa4a6da2690>. Skipping object. Exception encountered: Layer 'bn3' expected 4 variables, but received 0 variables during loading. Expected: ['bn3/gamma:0', 'bn3/beta:0', 'bn3/moving_mean:0', 'bn3/moving_variance:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6d5f110>. Skipping object. Exception encountered: Layer 'quant_relu3' expected 3 variables, but received 0 variables during loading. Expected: ['quant_relu3/optimizer_step:0', 'quant_relu3/output_min:0', 'quant_relu3/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce8fe0>. Skipping object. Exception encountered: Layer 'quant_pool3' expected 1 variables, but received 0 variables during loading. Expected: ['quant_pool3/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce9100>. Skipping object. Exception encountered: Layer 'quant_depthwise_conv4' expected 7 variables, but received 0 variables during loading. Expected: ['depthwise_conv4/depthwise_kernel:0', 'depthwise_conv4/depthwise_kernel:0', 'quant_depthwise_conv4/optimizer_step:0', 'quant_depthwise_conv4/depthwise_kernel_min:0', 'quant_depthwise_conv4/depthwise_kernel_max:0', 'quant_depthwise_conv4/post_activation_min:0', 'quant_depthwise_conv4/post_activation_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6c162d0>. Skipping object. Exception encountered: Layer 'quant_conv4' expected 5 variables, but received 0 variables during loading. Expected: ['conv4/kernel:0', 'conv4/kernel:0', 'quant_conv4/optimizer_step:0', 'quant_conv4/kernel_min:0', 'quant_conv4/kernel_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce8d40>. Skipping object. Exception encountered: Layer 'quant_bn4' expected 3 variables, but received 0 variables during loading. Expected: ['bn4/gamma:0', 'bn4/beta:0', 'quant_bn4/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:434: UserWarning: Could not load weights in object <tf_keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa4a6e47bf0>. Skipping object. Exception encountered: Layer 'bn4' expected 4 variables, but received 0 variables during loading. Expected: ['bn4/gamma:0', 'bn4/beta:0', 'bn4/moving_mean:0', 'bn4/moving_variance:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6c16570>. Skipping object. Exception encountered: Layer 'quant_conv4_proj' expected 5 variables, but received 0 variables during loading. Expected: ['conv4_proj/kernel:0', 'conv4_proj/kernel:0', 'quant_conv4_proj/optimizer_step:0', 'quant_conv4_proj/kernel_min:0', 'quant_conv4_proj/kernel_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce8ce0>. Skipping object. Exception encountered: Layer 'quant_relu4' expected 3 variables, but received 0 variables during loading. Expected: ['quant_relu4/optimizer_step:0', 'quant_relu4/output_min:0', 'quant_relu4/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ceab10>. Skipping object. Exception encountered: Layer 'quant_bn4_proj' expected 5 variables, but received 0 variables during loading. Expected: ['bn4_proj/gamma:0', 'bn4_proj/beta:0', 'quant_bn4_proj/optimizer_step:0', 'quant_bn4_proj/output_min:0', 'quant_bn4_proj/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:434: UserWarning: Could not load weights in object <tf_keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa4a6e47110>. Skipping object. Exception encountered: Layer 'bn4_proj' expected 4 variables, but received 0 variables during loading. Expected: ['bn4_proj/gamma:0', 'bn4_proj/beta:0', 'bn4_proj/moving_mean:0', 'bn4_proj/moving_variance:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce9610>. Skipping object. Exception encountered: Layer 'quant_skip_add' expected 1 variables, but received 0 variables during loading. Expected: ['quant_skip_add/optimizer_step:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce9190>. Skipping object. Exception encountered: Layer 'quant_relu4b' expected 3 variables, but received 0 variables during loading. Expected: ['quant_relu4b/optimizer_step:0', 'quant_relu4b/output_min:0', 'quant_relu4b/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce8710>. Skipping object. Exception encountered: Layer 'quant_gap' expected 3 variables, but received 0 variables during loading. Expected: ['quant_gap/optimizer_step:0', 'quant_gap/output_min:0', 'quant_gap/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce9460>. Skipping object. Exception encountered: Layer 'quant_fc1' expected 5 variables, but received 0 variables during loading. Expected: ['fc1/kernel:0', 'fc1/kernel:0', 'quant_fc1/optimizer_step:0', 'quant_fc1/kernel_min:0', 'quant_fc1/kernel_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ce8530>. Skipping object. Exception encountered: Layer 'quant_bn_fc1' expected 5 variables, but received 0 variables during loading. Expected: ['bn_fc1/gamma:0', 'bn_fc1/beta:0', 'quant_bn_fc1/optimizer_step:0', 'quant_bn_fc1/output_min:0', 'quant_bn_fc1/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:434: UserWarning: Could not load weights in object <tf_keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa4a6d5fc50>. Skipping object. Exception encountered: Layer 'bn_fc1' expected 4 variables, but received 0 variables during loading. Expected: ['bn_fc1/gamma:0', 'bn_fc1/beta:0', 'bn_fc1/moving_mean:0', 'bn_fc1/moving_variance:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tensorflow_model_optimization.python.core.quantization.keras.quantize_wrapper.QuantizeWrapperV2 object at 0x7aa4a6ceb9e0>. Skipping object. Exception encountered: Layer 'quant_relu_fc1' expected 3 variables, but received 0 variables during loading. Expected: ['quant_relu_fc1/optimizer_step:0', 'quant_relu_fc1/output_min:0', 'quant_relu_fc1/output_max:0']
#   _load_state(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/saving/saving_lib.py:511: UserWarning: Could not load weights in object <tf_keras.src.layers.core.dense.Dense object at 0x7aa4a6dee090>. Skipping object. Exception encountered: Layer 'output' expected 2 variables, but received 1 variables during loading. Expected: ['output/kernel:0', 'output/bias:0']
#   _load_state(
# 228/228 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9401
# Epoch 1: val_accuracy improved from -inf to 0.89693, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/qat_best.weights.h5
# 228/228 [==============================] - 18s 61ms/step - loss: 0.1585 - accuracy: 0.9401 - val_loss: 0.2303 - val_accuracy: 0.8969 - lr: 2.0000e-05
# Epoch 2/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9471
# Epoch 2: val_accuracy improved from 0.89693 to 0.90735, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/qat_best.weights.h5
# 228/228 [==============================] - 13s 59ms/step - loss: 0.1408 - accuracy: 0.9471 - val_loss: 0.2261 - val_accuracy: 0.9073 - lr: 2.0000e-05
# Epoch 3/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9475
# Epoch 3: val_accuracy improved from 0.90735 to 0.90789, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/qat_best.weights.h5
# 228/228 [==============================] - 13s 59ms/step - loss: 0.1446 - accuracy: 0.9475 - val_loss: 0.2256 - val_accuracy: 0.9079 - lr: 2.0000e-05
# Epoch 4/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1385 - accuracy: 0.9471
# Epoch 4: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1383 - accuracy: 0.9472 - val_loss: 0.2199 - val_accuracy: 0.9068 - lr: 2.0000e-05
# Epoch 5/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9444
# Epoch 5: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1425 - accuracy: 0.9444 - val_loss: 0.2199 - val_accuracy: 0.9062 - lr: 2.0000e-05
# Epoch 6/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9500
# Epoch 6: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 11s 50ms/step - loss: 0.1339 - accuracy: 0.9498 - val_loss: 0.2187 - val_accuracy: 0.9079 - lr: 2.0000e-05
# Epoch 7/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9472
# Epoch 7: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 12s 52ms/step - loss: 0.1353 - accuracy: 0.9472 - val_loss: 0.2167 - val_accuracy: 0.9073 - lr: 2.0000e-05
# Epoch 8/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9493
# Epoch 8: val_accuracy did not improve from 0.90789
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1310 - accuracy: 0.9493 - val_loss: 0.2227 - val_accuracy: 0.9062 - lr: 2.0000e-05
# Epoch 9/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9484
# Epoch 9: val_accuracy improved from 0.90789 to 0.91064, saving model to /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/qat_best.weights.h5
# 228/228 [==============================] - 14s 60ms/step - loss: 0.1299 - accuracy: 0.9485 - val_loss: 0.2215 - val_accuracy: 0.9106 - lr: 2.0000e-05
# Epoch 10/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9482
# Epoch 10: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 14s 60ms/step - loss: 0.1325 - accuracy: 0.9482 - val_loss: 0.2245 - val_accuracy: 0.9095 - lr: 2.0000e-05
# Epoch 11/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9498
# Epoch 11: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1268 - accuracy: 0.9496 - val_loss: 0.2231 - val_accuracy: 0.9024 - lr: 2.0000e-05
# Epoch 12/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9489
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 12: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 12s 55ms/step - loss: 0.1306 - accuracy: 0.9489 - val_loss: 0.2186 - val_accuracy: 0.9073 - lr: 2.0000e-05
# Epoch 13/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9506
# Epoch 13: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 13s 56ms/step - loss: 0.1291 - accuracy: 0.9507 - val_loss: 0.2235 - val_accuracy: 0.9079 - lr: 1.0000e-05
# Epoch 14/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1276 - accuracy: 0.9499
# Epoch 14: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 12s 53ms/step - loss: 0.1277 - accuracy: 0.9500 - val_loss: 0.2208 - val_accuracy: 0.9106 - lr: 1.0000e-05
# Epoch 15/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1276 - accuracy: 0.9489
# Epoch 15: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 12s 51ms/step - loss: 0.1275 - accuracy: 0.9489 - val_loss: 0.2207 - val_accuracy: 0.9073 - lr: 1.0000e-05
# Epoch 16/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9507
# Epoch 16: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 13s 55ms/step - loss: 0.1270 - accuracy: 0.9507 - val_loss: 0.2186 - val_accuracy: 0.9079 - lr: 1.0000e-05
# Epoch 17/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9515
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 17: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1219 - accuracy: 0.9513 - val_loss: 0.2212 - val_accuracy: 0.9079 - lr: 1.0000e-05
# Epoch 18/30
# 228/228 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9533
# Epoch 18: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1250 - accuracy: 0.9533 - val_loss: 0.2219 - val_accuracy: 0.9084 - lr: 5.0000e-06
# Epoch 19/30
# 227/228 [============================>.] - ETA: 0s - loss: 0.1292 - accuracy: 0.9478
# Epoch 19: val_accuracy did not improve from 0.91064
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1294 - accuracy: 0.9478 - val_loss: 0.2187 - val_accuracy: 0.9095 - lr: 5.0000e-06
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
#
# ✅ QAT model accuracy : 91.06%
#    Base model accuracy: 91.17%
#    QAT accuracy drop  : +0.11%  (target: < 1%)
# ⚠️  QAT accuracy 91.06% < 93% — kiểm tra lại base accuracy
# 💾 QAT weights saved: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/qat_weights.weights.h5

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 8: EXPORT INT8 TFLITE — fixed
# ═══════════════════════════════════════════════════════════════════════════
print("=" * 70)
print("STEP 8: EXPORT INT8 TFLITE (ASIC-READY)")
print("=" * 70)

converter = tf.lite.TFLiteConverter.from_keras_model(model_to_export)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Fix 5: tăng N_CALIB lên toàn bộ val set
# 200 mẫu thường không đủ để calibrate activation range chính xác
# Nguyên tắc: càng nhiều sample càng tốt, ít nhất 500-1000
N_CALIB = len(X_test)   # dùng toàn bộ test set làm calibration
print(f"📊 Calibration samples: {N_CALIB} (toàn bộ test set)")

def representative_dataset():
    # Fix 6: shuffle để đảm bảo diversity của calibration data
    idxs = np.random.permutation(N_CALIB)
    for i in idxs:
        sample = X_test[i:i+1].astype(np.float32)
        yield [sample]

converter.representative_dataset = representative_dataset

# Fix 7: thêm experimental_new_quantizer=True
# Dùng quantizer mới của TFLite, tốt hơn cho per-channel quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type      = tf.int8
converter.inference_output_type     = tf.int8

# Fix 8: experimental options để giảm accuracy drop
converter._experimental_disable_per_channel = False  # BẬT per-channel (mặc định)

print("Converting to INT8 TFLite... (có thể mất vài phút)")
tflite_model = converter.convert()

tflite_path = os.path.join(OUTPUT_PATH, 'drowsiness_asic_int8.tflite')
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)

print(f"\n✅ INT8 TFLite saved: {tflite_path}")
print(f"   Model size: {len(tflite_model)/1024:.1f} KB")
# Out:
# ======================================================================
# STEP 8: EXPORT INT8 TFLITE (ASIC-READY)
# ======================================================================
# 📊 Calibration samples: 1824 (toàn bộ test set)
# Converting to INT8 TFLite... (có thể mất vài phút)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ INT8 TFLite saved: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models/drowsiness_asic_int8.tflite
#    Model size: 81.8 KB

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 8.5: DIAGNOSTIC — tìm layer nào gây drop nhiều nhất
# ═══════════════════════════════════════════════════════════════════════════
print("=" * 70)
print("STEP 8.5: QUANTIZATION DIAGNOSTIC")
print("=" * 70)

# 1. Kiểm tra activation range của từng layer
# Range quá rộng → int8 không đủ resolution → accuracy drop
print("\n📊 Activation range per layer (dùng 100 mẫu):")
print(f"{'Layer':<40} {'Min':>10} {'Max':>10} {'Range':>10}")
print("-" * 72)

sample_batch = X_train[:100].astype(np.float32)

# Tạo model trung gian để lấy activation từng layer
activation_ranges = {}
for layer in base_model.layers:
    if not layer.weights:
        continue
    try:
        sub_model = tf.keras.Model(inputs=base_model.input, outputs=layer.output)
        acts = sub_model.predict(sample_batch, verbose=0)
        acts_flat = acts.flatten()
        act_min, act_max = acts_flat.min(), acts_flat.max()
        act_range = act_max - act_min
        activation_ranges[layer.name] = act_range
        # Cảnh báo range > 6 (ReLU6 sẽ clamp đúng, ReLU thường để range rất rộng)
        flag = " ⚠️  WIDE" if act_range > 10 else ""
        print(f"{layer.name:<40} {act_min:>10.4f} {act_max:>10.4f} {act_range:>10.4f}{flag}")
    except Exception:
        pass

# 2. Kiểm tra weight distribution
print(f"\n📊 Weight range per layer:")
print(f"{'Layer':<40} {'W_min':>10} {'W_max':>10} {'|W|_max':>10}")
print("-" * 72)
for layer in base_model.layers:
    if not layer.weights:
        continue
    for w in layer.weights:
        if 'kernel' in w.name:
            w_np = w.numpy().flatten()
            flag = " ⚠️  OUTLIER" if abs(w_np).max() > 3.0 else ""
            print(f"{layer.name:<40} {w_np.min():>10.4f} {w_np.max():>10.4f} "
                  f"{abs(w_np).max():>10.4f}{flag}")
# Out:
# ======================================================================
# STEP 8.5: QUANTIZATION DIAGNOSTIC
# ======================================================================
#
# 📊 Activation range per layer (dùng 100 mẫu):
# Layer                                           Min        Max      Range
# ------------------------------------------------------------------------
# depthwise_conv1                             -0.9008     0.5824     1.4833
# conv1                                       -0.3846     0.3517     0.7362
# bn1                                         -6.0191     5.8480    11.8671 ⚠️  WIDE
# depthwise_conv2                             -2.1260     1.9953     4.1212
# conv2                                       -2.0184     1.9615     3.9799
# bn2                                        -11.3646    11.1624    22.5270 ⚠️  WIDE
# depthwise_conv3                             -3.0837     2.2429     5.3266
# conv3                                       -2.6526     2.4985     5.1510
# bn3                                        -11.3934    10.0137    21.4071 ⚠️  WIDE
# depthwise_conv4                             -3.3896     2.7634     6.1530
# conv4                                       -2.7749     2.6354     5.4103
# bn4                                         -8.6847     9.1884    17.8731 ⚠️  WIDE
# conv4_proj                                 -21.1023    22.0935    43.1959 ⚠️  WIDE
# bn4_proj                                    -6.9732     7.6420    14.6152 ⚠️  WIDE
# fc1                                         -2.1413     1.7559     3.8972
# bn_fc1                                      -3.3985     3.8179     7.2164
# output                                      -7.5619     9.3429    16.9048 ⚠️  WIDE
#
# 📊 Weight range per layer:
# Layer                                         W_min      W_max    |W|_max
# ------------------------------------------------------------------------
# depthwise_conv1                             -0.6688     0.4435     0.6688
# conv1                                       -0.3904     0.4269     0.4269
# depthwise_conv2                             -0.2378     0.2175     0.2378
# conv2                                       -0.4261     0.4337     0.4337
# depthwise_conv3                             -0.2115     0.1960     0.2115
# conv3                                       -0.4162     0.3988     0.4162
# depthwise_conv4                             -0.2472     0.2217     0.2472
# conv4                                       -0.4026     0.4005     0.4026
# conv4_proj                                  -0.3737     0.3235     0.3737
# fc1                                         -0.3935     0.3656     0.3935
# output                                      -0.2097     0.1920     0.2097

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 9: VERIFY INT8 ACCURACY + SCALE FACTORS
# ═══════════════════════════════════════════════════════════════════════════
print("=" * 70)
print("STEP 9: VERIFY INT8 MODEL + SCALE FACTORS")
print("=" * 70)

interpreter = tf.lite.Interpreter(model_path=tflite_path)
interpreter.allocate_tensors()

input_details  = interpreter.get_input_details()
output_details = interpreter.get_output_details()

inp_detail = input_details[0]
inp_scale  = float(inp_detail['quantization_parameters']['scales'][0])
inp_zp     = int(inp_detail['quantization_parameters']['zero_points'][0])

print(f"\n📥 Input tensor:")
print(f"   Shape      : {inp_detail['shape']}")
print(f"   Dtype      : {inp_detail['dtype']}")
print(f"   Scale      : {inp_scale:.8f}")
print(f"   Zero point : {inp_zp}")

print(f"\n🔢 Quantization details:")
print(f"{'Index':>5}  {'Name':<45}  {'Dtype':<8}  {'Scale / Info'}")
print("-" * 90)

all_details = interpreter.get_tensor_details()
for t in all_details:
    qp = t['quantization_parameters']
    if len(qp['scales']) == 0:
        continue
    scales = qp['scales']
    zps    = qp['zero_points']
    if len(scales) == 1:
        scale_str = f"scale={scales[0]:.8f}, zp={zps[0]}"
    else:
        scale_str = f"per-channel {len(scales)} ch, scale[0]={scales[0]:.8f}"
    print(f"{t['index']:>5}  {t['name']:<45}  {str(t['dtype']):<8}  {scale_str}")

# Accuracy evaluation
print(f"\n📊 Đánh giá accuracy INT8 model...")
N_EVAL = min(len(X_test), 500)
correct = 0

out_zp = int(output_details[0]['quantization_parameters']['zero_points'][0])

for i in range(N_EVAL):
    sample = X_test[i:i+1].astype(np.float32)
    sample_int8 = np.round(sample / inp_scale + inp_zp).clip(-128, 127).astype(np.int8)

    interpreter.set_tensor(input_details[0]['index'], sample_int8)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])

    pred = 1 if int(output[0][0]) > out_zp else 0
    if pred == y_test[i]:
        correct += 1

int8_acc = correct / N_EVAL * 100

print(f"\n{'Model':<30} {'Accuracy':>10}")
print("-" * 42)
print(f"{'Float32 base model':<30} {base_acc*100:>9.2f}%")
if QAT_AVAILABLE:
    print(f"{'QAT model (fake-quant)':<30} {qat_acc*100:>9.2f}%")
print(f"{'INT8 TFLite (ASIC target)':<30} {int8_acc:>9.2f}%")
print(f"{'Accuracy drop vs float32':<30} {(base_acc*100 - int8_acc):>+9.2f}%")

if base_acc*100 - int8_acc < 2.0:
    print(f"\n✅ Accuracy drop < 2% — ĐẠT yêu cầu ASIC deployment")
else:
    print(f"\n⚠️  Accuracy drop > 2% — Xem xét tăng QAT epochs hoặc kiểm tra data")
# Out:
# ======================================================================
# STEP 9: VERIFY INT8 MODEL + SCALE FACTORS
# ======================================================================
#
# 📥 Input tensor:
#    Shape      : [  1 128 128   1]
#    Dtype      : <class 'numpy.int8'>
#    Scale      : 0.00411263
#    Zero point : -116
#
# 🔢 Quantization details:
# Index  Name                                           Dtype     Scale / Info
# ------------------------------------------------------------------------------------------
#     0  serving_default_input_q07:0                    <class 'numpy.int8'>  scale=0.00411263, zp=-116
#     2  tfl.pseudo_qconst                              <class 'numpy.int32'>  scale=0.00002287, zp=0
#     3  tfl.pseudo_qconst1                             <class 'numpy.int8'>  scale=0.00179478, zp=0
#     4  tfl.pseudo_qconst2                             <class 'numpy.int32'>  per-channel 64 ch, scale[0]=0.00010667
#     5  tfl.pseudo_qconst3                             <class 'numpy.int8'>  per-channel 64 ch, scale[0]=0.01634080
#     6  full_precision_model/quant_depthwise_conv1/depthwise;full_precision_model/quant_depthwise_conv1/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  scale=0.00528509, zp=0
#     7  tfl.pseudo_qconst8                             <class 'numpy.int32'>  scale=0.00002174, zp=0
#     8  full_precision_model/quant_depthwise_conv1/depthwise  <class 'numpy.int8'>  scale=0.01096540, zp=12
#     9  full_precision_model/quant_conv1/Conv2D;full_precision_model/quant_conv1/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 32 ch, scale[0]=0.00009859
#    10  tfl.pseudo_qconst4                             <class 'numpy.int32'>  per-channel 32 ch, scale[0]=0.00000108
#    11  full_precision_model/quant_relu1/Relu6;full_precision_model/quant_bn1/FusedBatchNormV3;full_precision_model/quant_conv1/Conv2D  <class 'numpy.int8'>  scale=0.02573917, zp=-98
#    12  full_precision_model/quant_pool1/MaxPool       <class 'numpy.int8'>  scale=0.02573917, zp=-98
#    13  full_precision_model/quant_depthwise_conv2/depthwise;full_precision_model/quant_depthwise_conv2/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 32 ch, scale[0]=0.00186974
#    14  tfl.pseudo_qconst7                             <class 'numpy.int32'>  per-channel 32 ch, scale[0]=0.00004813
#    15  full_precision_model/quant_depthwise_conv2/depthwise  <class 'numpy.int8'>  scale=0.01927015, zp=3
#    16  full_precision_model/quant_conv2/Conv2D;full_precision_model/quant_conv2/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 64 ch, scale[0]=0.01566687
#    17  tfl.pseudo_qconst31                            <class 'numpy.int32'>  per-channel 64 ch, scale[0]=0.00030190
#    18  full_precision_model/quant_relu2/Relu6;full_precision_model/quant_bn2/FusedBatchNormV3;full_precision_model/quant_conv2/Conv2D  <class 'numpy.int8'>  scale=0.02654931, zp=-99
#    19  full_precision_model/quant_pool2/MaxPool       <class 'numpy.int8'>  scale=0.02654931, zp=-99
#    20  full_precision_model/quant_depthwise_conv3/depthwise;full_precision_model/quant_depthwise_conv3/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 64 ch, scale[0]=0.00165496
#    21  tfl.pseudo_qconst6                             <class 'numpy.int32'>  per-channel 64 ch, scale[0]=0.00004394
#    22  full_precision_model/quant_depthwise_conv3/depthwise  <class 'numpy.int8'>  scale=0.02354236, zp=14
#    23  full_precision_model/quant_conv3/Conv2D;full_precision_model/quant_conv3/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 128 ch, scale[0]=0.01017026
#    24  tfl.pseudo_qconst21                            <class 'numpy.int32'>  per-channel 128 ch, scale[0]=0.00023943
#    25  full_precision_model/quant_relu3/Relu6;full_precision_model/quant_bn3/FusedBatchNormV3;full_precision_model/quant_conv3/Conv2D  <class 'numpy.int8'>  scale=0.02654931, zp=-99
#    26  full_precision_model/quant_pool3/MaxPool       <class 'numpy.int8'>  scale=0.02654931, zp=-99
#    27  full_precision_model/quant_conv4_proj/Conv2D;full_precision_model/quant_conv4_proj/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 128 ch, scale[0]=0.00165295
#    28  tfl.pseudo_qconst11                            <class 'numpy.int32'>  per-channel 128 ch, scale[0]=0.00004388
#    29  full_precision_model/quant_bn4_proj/FusedBatchNormV3;full_precision_model/quant_conv4_proj/Conv2D  <class 'numpy.int8'>  scale=0.05391155, zp=-5
#    30  full_precision_model/quant_depthwise_conv4/depthwise;full_precision_model/quant_depthwise_conv4/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 128 ch, scale[0]=0.00194445
#    31  tfl.pseudo_qconst5                             <class 'numpy.int32'>  per-channel 128 ch, scale[0]=0.00005162
#    32  full_precision_model/quant_depthwise_conv4/depthwise  <class 'numpy.int8'>  scale=0.02330271, zp=4
#    33  full_precision_model/quant_conv4/Conv2D;full_precision_model/quant_conv4/LastValueQuant/FakeQuantWithMinMaxVarsPerChannel  <class 'numpy.int8'>  per-channel 128 ch, scale[0]=0.01274169
#    34  tfl.pseudo_qconst9                             <class 'numpy.int32'>  per-channel 128 ch, scale[0]=0.00029692
#    35  full_precision_model/quant_relu4/Relu6;full_precision_model/quant_bn4/FusedBatchNormV3;full_precision_model/quant_conv4/Conv2D  <class 'numpy.int8'>  scale=0.02654931, zp=-99
#    36  full_precision_model/quant_relu4b/Relu6;full_precision_model/quant_skip_add/add  <class 'numpy.int8'>  scale=0.02654931, zp=-99
#    37  full_precision_model/quant_gap/Mean            <class 'numpy.int8'>  scale=0.01040414, zp=-54
#    38  full_precision_model/quant_fc1/MatMul;full_precision_model/quant_bn_fc1/batchnorm/mul_1;full_precision_model/quant_bn_fc1/batchnorm/add_1;full_precision_model/quant_relu_fc1/Relu6  <class 'numpy.int8'>  scale=0.01577427, zp=-79
#    39  StatefulPartitionedCall:0                      <class 'numpy.int8'>  scale=0.08035351, zp=-2
#
# 📊 Đánh giá accuracy INT8 model...
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# Model                            Accuracy
# ------------------------------------------
# Float32 base model                 91.17%
# QAT model (fake-quant)             91.06%
# INT8 TFLite (ASIC target)          48.40%
# Accuracy drop vs float32          +42.77%
#
# ⚠️  Accuracy drop > 2% — Xem xét tăng QAT epochs hoặc kiểm tra data

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 11: TRAINING REPORT + BIỂU ĐỒ
# ═══════════════════════════════════════════════════════════════════════════
print("=" * 70)
print("STEP 11: TRAINING REPORT")
print("=" * 70)

print("\n📋 Layer-by-layer architecture:")
print(f"{'#':<3}  {'Layer':<30}  {'Output shape':<20}  {'Params':>8}")
print("-" * 70)
for idx, layer in enumerate(base_model.layers):
    try:
        out_shape = str(layer.output_shape[1:])
    except Exception:
        out_shape = "N/A"
    n_params = layer.count_params()
    print(f"{idx:<3}  {layer.name:<30}  {out_shape:<20}  {n_params:>8,}")

def last(hist, key):
    return hist.history[key][-1]

print(f"\n{'─'*50}")
print(f"FINAL RESULTS SUMMARY")
print(f"{'─'*50}")

print(f"\n[Base Model — Float32]")
print(f"  Train accuracy : {last(history_base,'accuracy')*100:.2f}%")
print(f"  Val accuracy   : {last(history_base,'val_accuracy')*100:.2f}%")

if QAT_AVAILABLE:
    print(f"\n[QAT Model — Fake-Quant]")
    print(f"  Train accuracy : {last(history_qat,'accuracy')*100:.2f}%")
    print(f"  Val accuracy   : {last(history_qat,'val_accuracy')*100:.2f}%")

print(f"\n[INT8 TFLite — ASIC Target]")
print(f"  INT8 accuracy  : {int8_acc:.2f}%")
print(f"  Model size     : {len(tflite_model)/1024:.1f} KB")

# Biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("ASIC Driver Drowsiness — Training History", fontsize=14)

ax = axes[0]
ax.plot(history_base.history['accuracy'],     label='Base Train', color='steelblue')
ax.plot(history_base.history['val_accuracy'], label='Base Val',   color='steelblue', linestyle='--')
if QAT_AVAILABLE:
    offset = len(history_base.history['accuracy'])
    epochs_qat = range(offset, offset + len(history_qat.history['accuracy']))
    ax.plot(epochs_qat, history_qat.history['accuracy'],     label='QAT Train', color='darkorange')
    ax.plot(epochs_qat, history_qat.history['val_accuracy'], label='QAT Val',   color='darkorange', linestyle='--')
    ax.axvline(x=offset, color='gray', linestyle=':', alpha=0.7, label='QAT start')
ax.axhline(y=int8_acc/100, color='green', linestyle=':', alpha=0.8, label=f'INT8 ({int8_acc:.1f}%)')
ax.set_xlabel('Epoch'); ax.set_ylabel('Accuracy')
ax.set_title('Accuracy (Base → QAT → INT8)')
ax.legend(fontsize=8); ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(history_base.history['loss'],     label='Base Train', color='steelblue')
ax.plot(history_base.history['val_loss'], label='Base Val',   color='steelblue', linestyle='--')
if QAT_AVAILABLE:
    ax.plot(epochs_qat, history_qat.history['loss'],     label='QAT Train', color='darkorange')
    ax.plot(epochs_qat, history_qat.history['val_loss'], label='QAT Val',   color='darkorange', linestyle='--')
    ax.axvline(x=offset, color='gray', linestyle=':', alpha=0.7, label='QAT start')
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Loss (Base → QAT)')
ax.legend(fontsize=8); ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'training_history.png'), dpi=150)
plt.show()
print("📊 Biểu đồ đã lưu: training_history.png")

print("\n" + "=" * 70)
print("✅ COMPLETE QAT PIPELINE HOÀN THÀNH!")
print("=" * 70)
print(f"📁 Output files: {OUTPUT_PATH}")
print(f"  • base_weights.weights.h5")
if QAT_AVAILABLE:
    print(f"  • qat_weights.weights.h5")
print(f"  • drowsiness_asic_int8.tflite")
print(f"  • asic_weights.h")
print(f"  • training_history.png")
# Out:
# ======================================================================
# STEP 11: TRAINING REPORT
# ======================================================================
#
# 📋 Layer-by-layer architecture:
# #    Layer                           Output shape            Params
# ----------------------------------------------------------------------
# 0    input_q07                       []                           0
# 1    conv1                           (128, 128, 32)              41
# 2    bn1                             (128, 128, 32)             128
# 3    relu1                           (128, 128, 32)               0
# 4    pool1                           (64, 64, 32)                 0
# 5    conv2                           (64, 64, 64)             2,336
# 6    bn2                             (64, 64, 64)               256
# 7    relu2                           (64, 64, 64)                 0
# 8    pool2                           (32, 32, 64)                 0
# 9    conv3                           (32, 32, 128)            8,768
# 10   bn3                             (32, 32, 128)              512
# 11   relu3                           (32, 32, 128)                0
# 12   pool3                           (16, 16, 128)                0
# 13   conv4                           (16, 16, 128)           17,536
# 14   conv4_proj                      (16, 16, 128)           16,384
# 15   bn4                             (16, 16, 128)              512
# 16   bn4_proj                        (16, 16, 128)              512
# 17   relu4                           (16, 16, 128)                0
# 18   relu4_proj                      (16, 16, 128)                0
# 19   skip4                           (16, 16, 128)                0
# 20   relu4b                          (16, 16, 128)                0
# 21   gap                             (128,)                       0
# 22   fc1                             (64,)                    8,192
# 23   bn_fc1                          (64,)                      256
# 24   relu_fc                         (64,)                        0
# 25   drop1                           (64,)                        0
# 26   output                          (1,)                        65
#
# ──────────────────────────────────────────────────
# FINAL RESULTS SUMMARY
# ──────────────────────────────────────────────────
#
# [Base Model — Float32]
#   Train accuracy : 93.86%
#   Val accuracy   : 91.39%
#
# [QAT Model — Fake-Quant]
#   Train accuracy : 93.57%
#   Val accuracy   : 90.95%
#
# [INT8 TFLite — ASIC Target]
#   INT8 accuracy  : 51.60%
#   Model size     : 81.8 KB
# 📊 Biểu đồ đã lưu: training_history.png
#
# ======================================================================
# ✅ COMPLETE QAT PIPELINE HOÀN THÀNH!
# ======================================================================
# 📁 Output files: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models
#   • base_weights.weights.h5
#   • qat_weights.weights.h5
#   • drowsiness_asic_int8.tflite
#   • asic_weights.h
#   • training_history.png

# %%
# ═══════════════════════════════════════════════════════════════════════════
# STEP 11: TRAINING REPORT + BIỂU ĐỒ
# ═══════════════════════════════════════════════════════════════════════════
print("=" * 70)
print("STEP 11: TRAINING REPORT")
print("=" * 70)

print("\n📋 Layer-by-layer architecture:")
print(f"{'#':<3}  {'Layer':<30}  {'Output shape':<20}  {'Params':>8}")
print("-" * 70)
for idx, layer in enumerate(base_model.layers):
    try:
        out_shape = str(layer.output_shape[1:])
    except Exception:
        out_shape = "N/A"
    n_params = layer.count_params()
    print(f"{idx:<3}  {layer.name:<30}  {out_shape:<20}  {n_params:>8,}")

def last(hist, key):
    return hist.history[key][-1]

print(f"\n{'─'*50}")
print(f"FINAL RESULTS SUMMARY")
print(f"{'─'*50}")

print(f"\n[Base Model — Float32]")
print(f"  Train accuracy : {last(history_base,'accuracy')*100:.2f}%")
print(f"  Val accuracy   : {last(history_base,'val_accuracy')*100:.2f}%")

if QAT_AVAILABLE:
    print(f"\n[QAT Model — Fake-Quant]")
    print(f"  Train accuracy : {last(history_qat,'accuracy')*100:.2f}%")
    print(f"  Val accuracy   : {last(history_qat,'val_accuracy')*100:.2f}%")

print(f"\n[INT8 TFLite — ASIC Target]")
print(f"  INT8 accuracy  : {int8_acc:.2f}%")
print(f"  Model size     : {len(tflite_model)/1024:.1f} KB")

# Biểu đồ
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("ASIC Driver Drowsiness — Training History", fontsize=14)

ax = axes[0]
ax.plot(history_base.history['accuracy'],     label='Base Train', color='steelblue')
ax.plot(history_base.history['val_accuracy'], label='Base Val',   color='steelblue', linestyle='--')
if QAT_AVAILABLE:
    offset = len(history_base.history['accuracy'])
    epochs_qat = range(offset, offset + len(history_qat.history['accuracy']))
    ax.plot(epochs_qat, history_qat.history['accuracy'],     label='QAT Train', color='darkorange')
    ax.plot(epochs_qat, history_qat.history['val_accuracy'], label='QAT Val',   color='darkorange', linestyle='--')
    ax.axvline(x=offset, color='gray', linestyle=':', alpha=0.7, label='QAT start')
ax.axhline(y=int8_acc/100, color='green', linestyle=':', alpha=0.8, label=f'INT8 ({int8_acc:.1f}%)')
ax.set_xlabel('Epoch'); ax.set_ylabel('Accuracy')
ax.set_title('Accuracy (Base → QAT → INT8)')
ax.legend(fontsize=8); ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(history_base.history['loss'],     label='Base Train', color='steelblue')
ax.plot(history_base.history['val_loss'], label='Base Val',   color='steelblue', linestyle='--')
if QAT_AVAILABLE:
    ax.plot(epochs_qat, history_qat.history['loss'],     label='QAT Train', color='darkorange')
    ax.plot(epochs_qat, history_qat.history['val_loss'], label='QAT Val',   color='darkorange', linestyle='--')
    ax.axvline(x=offset, color='gray', linestyle=':', alpha=0.7, label='QAT start')
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Loss (Base → QAT)')
ax.legend(fontsize=8); ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'training_history.png'), dpi=150)
plt.show()
print("📊 Biểu đồ đã lưu: training_history.png")

print("\n" + "=" * 70)
print("✅ COMPLETE QAT PIPELINE HOÀN THÀNH!")
print("=" * 70)
print(f"📁 Output files: {OUTPUT_PATH}")
print(f"  • base_weights.weights.h5")
if QAT_AVAILABLE:
    print(f"  • qat_weights.weights.h5")
print(f"  • drowsiness_asic_int8.tflite")
print(f"  • asic_weights.h")
print(f"  • training_history.png")
# Out:
# ======================================================================
# STEP 11: TRAINING REPORT
# ======================================================================
#
# 📋 Layer-by-layer architecture:
# #    Layer                           Output shape            Params
# ----------------------------------------------------------------------
# 0    input_q07                       []                           0
# 1    conv1                           (128, 128, 32)              41
# 2    relu1                           (128, 128, 32)               0
# 3    pool1                           (64, 64, 32)                 0
# 4    conv2                           (64, 64, 64)             2,336
# 5    relu2                           (64, 64, 64)                 0
# 6    pool2                           (32, 32, 64)                 0
# 7    conv3                           (32, 32, 128)            8,768
# 8    relu3                           (32, 32, 128)                0
# 9    pool3                           (16, 16, 128)                0
# 10   conv4                           (16, 16, 128)           17,536
# 11   relu4                           (16, 16, 128)                0
# 12   gap                             (128,)                       0
# 13   fc1                             (32,)                    4,128
# 14   relu_fc                         (32,)                        0
# 15   output                          (1,)                        33
#
# ──────────────────────────────────────────────────
# FINAL RESULTS SUMMARY
# ──────────────────────────────────────────────────
#
# [Base Model — Float32]
#   Train accuracy : 85.99%
#   Val accuracy   : 85.20%
#
# [QAT Model — Fake-Quant]
#   Train accuracy : 86.76%
#   Val accuracy   : 85.47%
#
# [INT8 TFLite — ASIC Target]
#   INT8 accuracy  : 83.80%
#   Model size     : 54.4 KB
# 📊 Biểu đồ đã lưu: training_history.png
#
# ======================================================================
# ✅ COMPLETE QAT PIPELINE HOÀN THÀNH!
# ======================================================================
# 📁 Output files: /content/drive/MyDrive/Colab Notebooks/DriverDrowsiness/Models
#   • base_weights.weights.h5
#   • qat_weights.weights.h5
#   • drowsiness_asic_int8.tflite
#   • asic_weights.h
#   • training_history.png
